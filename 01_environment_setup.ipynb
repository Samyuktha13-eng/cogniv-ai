# %%
import sys
import platform

print("Python:", sys.version)
print("Platform:", platform.platform())
# Out:
# Python: 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# Platform: Windows-11-10.0.26200-SP0

# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\dmane\anaconda3\lib\site-packages (2.14.0)
# Requirement already satisfied: torchvision in c:\users\dmane\anaconda3\lib\site-packages (0.29.0)
# Requirement already satisfied: torchaudio in c:\users\dmane\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: filelock in c:\users\dmane\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\dmane\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\dmane\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\dmane\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\dmane\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\dmane\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\dmane\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\dmane\anaconda3\lib\site-packages (from torchvision) (2.5.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\dmane\anaconda3\lib\site-packages (from torchvision) (12.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dmane\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dmane\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print(
        "CUDA version:",
        torch.version.cuda
    )
else:
    print("Running without CUDA GPU.")
# Out:
# PyTorch version: 2.14.0+cpu
# CUDA available: False
# Running without CUDA GPU.

# %%
pip install -U pydantic pydantic-settings python-dotenv
# Out:
# Requirement already satisfied: pydantic in c:\users\dmane\anaconda3\lib\site-packages (2.13.5)
# Requirement already satisfied: pydantic-settings in c:\users\dmane\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: python-dotenv in c:\users\dmane\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dmane\anaconda3\lib\site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\users\dmane\anaconda3\lib\site-packages (from pydantic) (2.46.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\dmane\anaconda3\lib\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dmane\anaconda3\lib\site-packages (from pydantic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U langgraph langchain langchain-core
# Out:
# Requirement already satisfied: langgraph in c:\users\dmane\anaconda3\lib\site-packages (1.2.11)
# Requirement already satisfied: langchain in c:\users\dmane\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-core in c:\users\dmane\anaconda3\lib\site-packages (1.6.2)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\dmane\anaconda3\lib\site-packages (from langgraph) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\dmane\anaconda3\lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\dmane\anaconda3\lib\site-packages (from langgraph) (0.4.4)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\dmane\anaconda3\lib\site-packages (from langgraph) (2.13.5)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\dmane\anaconda3\lib\site-packages (from langgraph) (4.0.1)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\users\dmane\anaconda3\lib\site-packages (from langchain-core) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\dmane\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\dmane\anaconda3\lib\site-packages (from langchain-core) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\dmane\anaconda3\lib\site-packages (from langchain-core) (0.12.2)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\dmane\anaconda3\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\dmane\anaconda3\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dmane\anaconda3\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\dmane\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\dmane\anaconda3\lib\site-packages (from langchain-core) (0.17.1)
# Requirement already satisfied: anyio in c:\users\dmane\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (4.10.0)
# Requirement already satisfied: certifi in c:\users\dmane\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\dmane\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\dmane\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (3.19)
# Requirement already satisfied: h11>=0.16 in c:\users\dmane\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dmane\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\dmane\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\dmane\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in c:\users\dmane\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in c:\users\dmane\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in c:\users\dmane\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dmane\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\dmane\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dmane\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dmane\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.24.0)
# Requirement already satisfied: httpcore2==2.12.0 in c:\users\dmane\anaconda3\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in c:\users\dmane\anaconda3\lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (0.10.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dmane\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\users\dmane\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dmane\anaconda3\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dmane\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dmane\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U firebase-admin
# Out:
# Requirement already satisfied: firebase-admin in c:\users\dmane\anaconda3\lib\site-packages (7.5.0)
# Requirement already satisfied: cachecontrol>=0.14.3 in c:\users\dmane\anaconda3\lib\site-packages (from firebase-admin) (0.14.4)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.25.1 in c:\users\dmane\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.36.0)
# Requirement already satisfied: google-cloud-firestore>=2.21.0 in c:\users\dmane\anaconda3\lib\site-packages (from firebase-admin) (2.30.0)
# Requirement already satisfied: google-cloud-storage>=3.1.1 in c:\users\dmane\anaconda3\lib\site-packages (from firebase-admin) (3.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\dmane\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->firebase-admin) (2.10.1)
# Requirement already satisfied: httpx==0.28.1 in c:\users\dmane\anaconda3\lib\site-packages (from httpx[http2]==0.28.1->firebase-admin) (0.28.1)
# Requirement already satisfied: anyio in c:\users\dmane\anaconda3\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (4.10.0)
# Requirement already satisfied: certifi in c:\users\dmane\anaconda3\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\dmane\anaconda3\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.0.9)
# Requirement already satisfied: idna in c:\users\dmane\anaconda3\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (3.19)
# Requirement already satisfied: h2<5,>=3 in c:\users\dmane\anaconda3\lib\site-packages (from httpx[http2]==0.28.1->firebase-admin) (4.4.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.69.2 in c:\users\dmane\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.75.3)
# Requirement already satisfied: protobuf<8.0.0,>=6.33.5 in c:\users\dmane\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (7.36.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.26.1 in c:\users\dmane\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.28.4)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\dmane\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.57.1)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in c:\users\dmane\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.34.2)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.44.0 in c:\users\dmane\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.44.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.59.0 in c:\users\dmane\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.83.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.59.0 in c:\users\dmane\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.83.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dmane\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\dmane\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (46.0.3)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\dmane\anaconda3\lib\site-packages (from grpcio<2.0.0,>=1.59.0->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (4.15.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\dmane\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.2 in c:\users\dmane\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (4.2.0)
# Requirement already satisfied: h11>=0.16 in c:\users\dmane\anaconda3\lib\site-packages (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dmane\anaconda3\lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dmane\anaconda3\lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.5.0)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in c:\users\dmane\anaconda3\lib\site-packages (from cachecontrol>=0.14.3->firebase-admin) (1.1.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\dmane\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\dmane\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.23)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.0.0 in c:\users\dmane\anaconda3\lib\site-packages (from google-cloud-firestore>=2.21.0->firebase-admin) (2.7.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in c:\users\dmane\anaconda3\lib\site-packages (from google-cloud-storage>=3.1.1->firebase-admin) (2.10.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.6.0 in c:\users\dmane\anaconda3\lib\site-packages (from google-cloud-storage>=3.1.1->firebase-admin) (1.8.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\dmane\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dmane\anaconda3\lib\site-packages (from anyio->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U fastapi uvicorn httpx
# Out:
# Requirement already satisfied: fastapi in c:\users\dmane\anaconda3\lib\site-packages (0.141.1)
# Requirement already satisfied: uvicorn in c:\users\dmane\anaconda3\lib\site-packages (0.52.4)
# Requirement already satisfied: httpx in c:\users\dmane\anaconda3\lib\site-packages (0.28.1)
# Requirement already satisfied: starlette>=0.46.0 in c:\users\dmane\anaconda3\lib\site-packages (from fastapi) (1.6.0)
# Requirement already satisfied: pydantic>=2.9.0 in c:\users\dmane\anaconda3\lib\site-packages (from fastapi) (2.13.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dmane\anaconda3\lib\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dmane\anaconda3\lib\site-packages (from fastapi) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\dmane\anaconda3\lib\site-packages (from fastapi) (0.0.5)
# Requirement already satisfied: click>=7.0 in c:\users\dmane\anaconda3\lib\site-packages (from uvicorn) (8.2.1)
# Requirement already satisfied: h11>=0.8 in c:\users\dmane\anaconda3\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: anyio in c:\users\dmane\anaconda3\lib\site-packages (from httpx) (4.10.0)
# Requirement already satisfied: certifi in c:\users\dmane\anaconda3\lib\site-packages (from httpx) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\dmane\anaconda3\lib\site-packages (from httpx) (1.0.9)
# Requirement already satisfied: idna in c:\users\dmane\anaconda3\lib\site-packages (from httpx) (3.19)
# Requirement already satisfied: colorama in c:\users\dmane\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dmane\anaconda3\lib\site-packages (from pydantic>=2.9.0->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\users\dmane\anaconda3\lib\site-packages (from pydantic>=2.9.0->fastapi) (2.46.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dmane\anaconda3\lib\site-packages (from anyio->httpx) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U pandas numpy matplotlib pillow
# Out:
# Requirement already satisfied: pandas in c:\users\dmane\anaconda3\lib\site-packages (3.0.5)
# Requirement already satisfied: numpy in c:\users\dmane\anaconda3\lib\site-packages (2.5.3)
# Requirement already satisfied: matplotlib in c:\users\dmane\anaconda3\lib\site-packages (3.11.1)
# Requirement already satisfied: pillow in c:\users\dmane\anaconda3\lib\site-packages (12.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dmane\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\dmane\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dmane\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dmane\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\dmane\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dmane\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\dmane\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dmane\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\dmane\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
